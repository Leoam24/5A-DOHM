# %% [markdown]
# # 1) Utiliser d’abord l’outil ot_grammar_tester.exe pour tester chacune des
# grammaires fournies. Comprendre ce qu’elles font, comment cela est
# implémenté et quel est le résultat produit.
# - chiffres.grxml
# - chiffres_v2.grxml
# - grammaire_nombre_v3.grxml
# - grammaire_num_ab_v2.grxml
# - grammaire_act_lang_confirmation_v2.grxml
# - grammaire_aide.grxml
# - grammaire_dates_v3.grxml

# %% [markdown]
# ## Test de la grammaire chiffres.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/chiffres.grxml
Enter an utternace or press Enter to finish:
un
Semantic result: "un"
Enter an utternace or press Enter to finish:
deux
Semantic result: "deux"
Enter an utternace or press Enter to finish:
trois*
DOES NOT MATCH
Enter an utternace or press Enter to finish:
dix
DOES NOT MATCH
Enter an utternace or press Enter to finish:
zero
Semantic result: "zero"

# %% [markdown]
# On remarque que cette grammaire prend bel et bien en compte que les chiffres donc de Zero à neuf.
# Elle prend en entrée une chaine de caracteres et en sortie, nous renvoie cette meme chaine de caractere.

# %% [markdown]
# ## Test de la grammaire chiffres_v2.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/chiffres_v2.grxml
Enter an utternace or press Enter to finish:
un
Semantic result: {
  nb: 1
}
Enter an utternace or press Enter to finish:
deux
Semantic result: {
  nb: 2
}
Enter an utternace or press Enter to finish:
zero
Semantic result: {
  nb: 0
}
Enter an utternace or press Enter to finish:
dix
DOES NOT MATCH
Enter an utternace or press Enter to finish:
trois*
DOES NOT MATCH

# %% [markdown]
# La gramaire chiffres_v2 fait le meme travail que la v1, en ajoutant le symbole associé au chiffre cela est grace aux balises "tag".
# Cela pourra etre pratique pour des applicastions type calcul.

# %% [markdown]
# ## Test de la grammaire gramaire_nombre_v3.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/grammaire_nombre_v3.grxml
Enter an utternace or press Enter to finish:
douze mille
Semantic result: {
  nb: 12000,
  text: "douze mille"
}
Enter an utternace or press Enter to finish:
cent quatre vingt
Semantic result: {
  nb: 180,
  text: "cent quatre vingt"
}
Enter an utternace or press Enter to finish:
cent mille deux cent
Semantic result: {
  nb: 100200,
  text: "cent mille deux cent"
}
Enter an utternace or press Enter to finish:
zero
Semantic result: {
  nb: 0,
  text: "zero"
}
Enter an utternace or press Enter to finish:
soixante et onze
Semantic result: {
  nb: 71,
  text: "soixante et onze"
}
Enter an utternace or press Enter to finish:
un million
DOES NOT MATCH
Enter an utternace or press Enter to finish:
neuf cent quatre vingt dix neuf mille neuf cent quatre vingt dix neuf
Semantic result: {
  nb: 999999,
  text: "neuf cent quatre vingt dix neuf mille neuf cent quatre vingt dix neuf"
}

# %% [markdown]
# La grammaire "gramaire_nombre_v3", permet les memes choses que chiffres_v2 mais étendu de 0 à 999 999.
# La grammaire ecrit en dur les cas particuliers tel que 0 ou bien 71, puis se sert des regles concernant les dizaines, centaines, etc pour les enregistrer des dans des ruleref

# %% [markdown]
# ## Test de la grammaire grammaire_num_ab_v2.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/grammaire_num_ab_v2.grxml
Enter an utternace or press Enter to finish:
le dix
Semantic result: {
  nb: 10,
  text: "dix"
}
Enter an utternace or press Enter to finish:
c est le vingt
Semantic result: {
  nb: 20,
  text: "vingt"
}
Enter an utternace or press Enter to finish:
mon numero est le deux
Semantic result: {
  nb: 2,
  text: "deux"
}
Enter an utternace or press Enter to finish:
je suis le quatre
Semantic result: {
  nb: 4,
  text: "quatre"
}

# %% [markdown]
# La grammaire "grammaire_num_ab_v2", reprends "gramaire_nombre_v3" tout en y ajoutant la possibilité de rajouter du contexte en debut de phrase tel que :
#
# c est  le
# mon numero est le
# le
# je suis l abonne numero
# je suis le
#
# Donc on a une entrée deja plus "naturelle" et en sortie en on ne garde que le numero (son symbole ainsi que sa chaine de caractere)

# %% [markdown]
# ## Test de la grammaire grammaire_act_lang_confirmation_v2.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/grammaire_act_lang_confirmation_v2.grxml
Enter an utternace or press Enter to finish:
oui
Semantic result: "True"
Enter an utternace or press Enter to finish:
non
Semantic result: "False"
Enter an utternace or press Enter to finish:
merci
DOES NOT MATCH
Enter an utternace or press Enter to finish:
non merci
Semantic result: "False"

# %% [markdown]
# La grammaire "grammaire_act_lang_confirmation_v2" reconnait la negation et l'affirmation sous differentes facon et renoie True ou False. Il prend aussi en compte la politesse mais n'est pas une necessitée, c'est grace à l'item repeat="0-1"
# qui check si il y a une grammaire liée à la politesse ou non, et si oui le prend en compte sinon ne fait rien.

# %% [markdown]
# ## Test de la grammaire grammaire_aide.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/grammaire_aide.grxml
Enter an utternace or press Enter to finish:
quoi faire
Semantic result: "quoi faire"
Enter an utternace or press Enter to finish:
je voudrais de l aide
Semantic result: "je voudrais de l aide"
Enter an utternace or press Enter to finish:
excusez-moi aide
Semantic result: "excusez-moi aide"
Enter an utternace or press Enter to finish:
excusez-moi
DOES NOT MATCH
Enter an utternace or press Enter to finish:
excusez-moi quoi faire
Semantic result: "excusez-moi quoi faire"

# %% [markdown]
# La grammaire "grammaire_aide", regroupe le vocabulaire d'aide.
# ces expression sont facultatifs :
# excusez-moi
# pouvez-vous m
# svp
# je voudrais de l
# je voudrais savoir
#
# tandis que celles si sont necessaire :
# quoi faire
# faire quoi
# faire
# aider
# aide
#
# toujours une histoire de repeat="0-1"

# %% [markdown]
# ## Test de la grammaire grammaire_dates_v3.grxml

# %%
Testing grammar file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/grammaire_dates_v3.grxml
Enter an utternace or press Enter to finish:
deux janvier
Semantic result: {
  num_jour: -1,
  nb_jour: 2,
  num_mois: 0,
  nb_annee: 0
}
Enter an utternace or press Enter to finish:
2 janvier
DOES NOT MATCH
Enter an utternace or press Enter to finish:
zero decembre
Semantic result: {
  num_jour: -1,
  nb_jour: 0,
  num_mois: 11,
  nb_annee: 0
}
Enter an utternace or press Enter to finish:
trente quatre avril
Semantic result: {
  num_jour: -1,
  nb_jour: 34,
  num_mois: 3,
  nb_annee: 0
}
Enter an utternace or press Enter to finish:
vingt quatre mai deux mille quatre
Semantic result: {
  num_jour: -1,
  nb_jour: 24,
  num_mois: 4,
  nb_annee: 2004
}

# %% [markdown]
# La grammaire "grammaire_dates_v3", permet de decouper une date en entrée sous forme d'une chaine de caractere pour la remettre sous forme d'un dictionnaire.
# Cependant elle ne verifie pas vraiment si les jours sont corrects ou pas ( 0 janvier, 34 avril,...)
# Les dates sans années sont acceptées

# %% [markdown]
# # 2) Utiliser l’outil ot_vxml_interpreter.exe pour exécuter la version V0 de l’application qui vous est fournie et analyser le contenu du fichier vxml (éditer le fichier en parallèle).

# %%
Interpreting VoiceXML document file:/C:/Users/hml4654a/Documents/5A-DOHM/AGENDA_V0/AGENDA_V0/gestion_agenda_v0.vxml

Bienvenue sur le service de gestion de votre agenda. Aujourd'hui nous sommes le
Thu Dec 09 2010 15:30:00 GMT+0100
1291905000000
Quel est votre numero d'abonne ?
KEYB>neuf
Votre numero d'abonne est le
neuf
TRACE VALEUR
9
Pouvez-vous me le confirmer ?
KEYB> oui
TRACE Reponse
TRACE Numero confirme
Veuillez patienter ... Nous nous connectons a la base abonne.... Bonjour Monsieur Dupont. Vous pouvez maintenant acceder a votre agenda !
